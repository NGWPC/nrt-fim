# %%
from datetime import datetime
from pathlib import Path

import matplotlib.pyplot as plt
import rioxarray
from matplotlib.colors import LinearSegmentedColormap

import trainer

# %%
start_time = datetime.strptime("20190524 120000", "%Y%m%d %H%M%S")
end_time = datetime.strptime("20190527 110000", "%Y%m%d %H%M%S")
ds_r, ds_sm = trainer.read(start_time, end_time)

# %%
ds_r
# Out:
# <xarray.DataArray 'qSfcLatRunoff' (time: 72, feature_id: 2776734)> Size: 2GB
# [199924848 values with dtype=float64]
# Coordinates:
#     elevation   (feature_id) float32 11MB ...
#   * feature_id  (feature_id) int64 22MB 101 179 181 ... 1180001803 1180001804
#     gage_id     (feature_id) |S15 42MB ...
#     latitude    (feature_id) float32 11MB ...
#     longitude   (feature_id) float32 11MB ...
#     order       (feature_id) int32 11MB ...
#   * time        (time) datetime64[ns] 576B 2019-05-24T12:00:00 ... 2019-05-27...
# Attributes:
#     grid_mapping:  crs
#     long_name:     Runoff from terrain routing
#     units:         m3 s-1
#     valid_range:   [0, 2000000000]

# %%
ds_sm
# Out:
# <xarray.DataArray 'SOIL_M' (time: 24, y: 3840, soil_layers_stag: 4, x: 4608)> Size: 14GB
# [1698693120 values with dtype=float64]
# Coordinates:
#   * time     (time) datetime64[ns] 192B 2019-05-24T12:00:00 ... 2019-05-27T09...
#   * x        (x) float64 37kB -2.303e+06 -2.302e+06 ... 2.303e+06 2.304e+06
#   * y        (y) float64 31kB -1.92e+06 -1.919e+06 ... 1.918e+06 1.919e+06
# Dimensions without coordinates: soil_layers_stag
# Attributes:
#     esri_pe_string:  PROJCS["Lambert_Conformal_Conic",GEOGCS["GCS_Sphere",DAT...
#     grid_mapping:    crs
#     long_name:       volumetric soil moisture, the dimensionless ratio of wat...
#     units:           m3 m-3
#     valid_range:     [0, 100]
